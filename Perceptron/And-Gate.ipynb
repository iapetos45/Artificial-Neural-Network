# %%
# def And(x1, x2):
#     w1, w2, theta = 
#     tmp = x1*w1 + x2*w2
#     if temp <= theta:
#         return 0
#     elif tmp > theta:
#         return 1

# 가중치와 편향 도입
import numpy as np
def And(x1, x2):
    x = np.array([x1, x2]) # 입력
    w = np.array([0.5, 0.5]) # 가중치
    b = -0.7 # bias (편향)
    tmp = np.sum(w*x + b)
    if tmp <= 0:
        return 0
    else:
        return 1

# %%
And(0, 0)
# Out:
# 0

# %%
And(1, 0)
# Out:
# 0

# %%
And(0, 1)
# Out:
# 0

# %%
And(1, 1)
# Out:
# 0
