# %%
import numpy as np
import matplotlib.pylab as plt

# %%
# 다차원 배열
A = np.array([1, 2, 3, 4])
print("A = ", A)
print("A.ndim =", np.ndim(A))
print("A.shape = ", A.shape)
# Out:
# A =  [1 2 3 4]
# A.ndim = 1
# A.shape =  (4,)

# %%
B = np.array([[1, 2], [3, 4], [5, 6]])
print("B = ", B)
print("B.ndim =", np.ndim(B))
print("B.shape = ", B.shape)
# Out:
# B =  [[1 2]
#  [3 4]
#  [5 6]]
# B.ndim = 2
# B.shape =  (3, 2)

# %%
# 행렬의 내적 (행렬 곱)
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
print("A.shape = ", A.shape)
print("B.shape = ", B.shape)
# Out:
# A.shape =  (2, 2)
# B.shape =  (2, 2)

# %%
result = np.dot(A, B)
print("A*B =", result)
print("result.shape =", result.shape)
# Out:
# A*B = [[19 22]
#  [43 50]]
# result.shape = (2, 2)

# %%
C = np.array([[1, 2], [3, 4]])
print("C.shape =", C.shape)
print("A*C =", np.dot(A, C))
# Out:
# C.shape = (2, 2)
# A*C = [[ 7 10]
#  [15 22]]

# %%
A = np.array([[1, 2], [3, 4], [5, 6]])
print("A.shape =", A.shape)
B = np.array([7, 8])
print("B.shape =", B.shape)
print("A*B = ", np.dot(A, B))
# Out:
# A.shape = (3, 2)
# B.shape = (2,)
# A*B =  [23 53 83]

# %%
# 신경망의 내적
x = np.array([1, 2])
print("shape of input =", x.shape)
weight = np.array([[1, 3, 5], [2, 4, 6]])
print("weight =", weight)
print('shape of weight =', weight.shape)
y = np.dot(x, weight)
print("y =", y)
# Out:
# shape of input = (2,)
# weight = [[1 3 5]
#  [2 4 6]]
# shape of weight = (2, 3)
# y = [ 5 11 17]

# %%
# 각 층별 신호 전달 구현
x = np.array([1.0, 0.5])
weight1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
bias1 = np.array([0.1, 0.2, 0.3])
print("shape of input =", x.shape)
print("shape of weight1 =", weight1.shape)
print("shape of bias1 =", bias1.shape)
# Out:
# shape of input = (2,)
# shape of weight1 = (2, 3)
# shape of bias1 = (3,)

# %%
result_of_inner1 = np.dot(x, weight1) + bias1
result_of_sigmoid1 = sigmoid(result_of_inner1)
print("result of inner1 =", result_of_inner1)
print("result of sigmoid1 =", result_of_sigmoid1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ab98a8f8cbcf> in <module>()
#       1 result_of_inner1 = np.dot(x, weight1) + bias1
# ----> 2 result_of_sigmoid1 = sigmoid(result_of_inner1)
#       3 print("result of inner1 =", result_of_inner1)
#       4 print("result of sigmoid1 =", result_of_sigmoid1)
#
# NameError: name 'sigmoid' is not defined

# %%
# 각 층별 신호 전달 구현
weight2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
bias2 = np.array([0.1, 0.2])
print("shape of sigmoid1 =", result_of_sigmoid.shape)
print("shape of weight2 =", weight2.shape)
print("shape of bias2 =", bias2.shape)

# %%
result_of inner2 = np.dot(result_of_sigmoid1, weight2) + bias2
result_of_sigmoid2 = sigmoid(result_of_inner2)
print("result of inner1 =", result_of inner2)
print("result of sigmoid1 =" result_of_sigmoid2)
# 오탈자 찾아야 함

# %%
# part of activation function
def identity_foundation(x):
    return

# %%
weight3 = np.array([0.1, 0.3], [0.2, 0.4])
bias = np.array([0.1, 0.2])
print("shape of sigmoid2 =", result_of_sigmoid2.shape)
print("shape of weight3 =", weight3.shape)
print("shape of bias3 =", bias3.shape)

# %%
result_of_inner3 = np.dot(result_of_sigmoid2, weight3) + bias3
output = identity_function(result_of_inner3)
print("output =", output)

# %%
def init_network():
    network = {}
    network["weight1"] = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
    network["bias1"] = np.array([0.1, 0.2, 0.3])
    network["weight2"] = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
    network["bias2"] = np.array([0.1, 0.2])
    network["weight3"] = np.array([[0.1, 0.3], [0.2, 0.4]])
    network["bias3"] = np.array([0.1, 0.2])
    
    return nwtwork

# %%
def forward(network, x):
    weight1, weight2, weight3 = network["weight1"], network["weight2"], network["weight3"]
    bias1, bias2, bias3 = network["bias1"], network["bias2"], network["bias3"]
    
    result_of_inner1 = np.dot(x, weight1) + bias1
    output1 = sigmoid(result_of_inner1)
    result_of_inner2 = np.dot(output1, weight1) + bias2
    output2 = sigmoid(result_of_inner2)
    result_of_inner3 = np.dot(output2, weight3) + bias3
    y = indentity_function(result_of_inner3)
    
    return y

# %%
network = int_network()
x = np.array([1.0, 0.5])
y = forward(network, x)
print(y)
