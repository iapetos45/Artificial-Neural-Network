# %%
import numpy as np
import matplotlib.pylab as plt

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = step_function(x)
plt.figure(figsize = (15, 10))
plt.ylim(-0.1, 1.1) # y축 범위 지점
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1e963e98502c> in <module>()
#       1 X = np.arange(-5.0, 5.0, 0.1)
# ----> 2 Y = step_function(x)
#       3 plt.figure(figsize = (15, 10))
#       4 plt.ylim(-0.1, 1.1) # y축 범위 지점
#       5 plt.show
#
# NameError: name 'step_function' is not defined
