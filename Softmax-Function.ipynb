# %%
import numpy as np
import matplotlib.pylab as plt

# %%
# def softmax(matrix):
#     exponential_matrix = np.exp(matrix)
#     sum_of_exponential_matrix = np.sum(exponential_matrix)
#     y = exponential_matrix / sum_of_exponential_matrix

# %%
# matrix = np.array([1010, 1000, 900])
# result_of_softmax = np.exp(matrix) / np.sum(np.exp(matrix))
# print(result_of_softmax)

# %%
def softmax(matrix):
    exponential_matrix = np.exp(matrix)
    difference_from_maximum = matrix - maximum_of_matrix
    exponential_of_differencce = np.exp(difference_from_maximum)
    sum_of_exponential = np.sum(exponential_of_difference)
    y = exponential_of_matrix / sum_of_exponential
    
    return y

# %%
matrix = np.array([0.3, 2.9, 4.0])
y = softmax(matrix)
print("y =", y)
print("sum of y=", np.sum(y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0c6140035ba5> in <module>()
#       1 matrix = np.array([0.3, 2.9, 4.0])
# ----> 2 y = softmax(matrix)
#       3 print("y =", y)
#       4 print("sum of y=", np.sum(y))
#
# <ipython-input-4-7093a4ee8b6c> in softmax(matrix)
#       1 def softmax(matrix):
#       2     exponential_matrix = np.exp(matrix)
# ----> 3     difference_from_maximum = matrix - maximum_of_matrix
#       4     exponential_of_differencce = np.exp(difference_from_maximum)
#       5     sum_of_exponential = np.sum(exponential_of_difference)
#
# NameError: name 'maximum_of_matrix' is not defined
